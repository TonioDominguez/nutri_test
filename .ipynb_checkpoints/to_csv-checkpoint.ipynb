# %% [markdown]
# ## CONVERSIÓN PDF EN CSV CON RECETAS

# %%
import pandas as pd
import pdfplumber
import re

def leer_pdf(ruta_archivo):
    texto_completo = ""
    try:
        with pdfplumber.open(ruta_archivo) as pdf:
            for pagina in pdf.pages:
                texto_completo += pagina.extract_text() + "\n"
        return texto_completo
    except Exception as e:
        print(f"Error al leer el PDF: {e}")
        return None

def extraer_raciones(texto):
    patrones = [
        r'(\d+)\s*[Rr]aciones?',
        r'(\d+)/(\d+)\s*ración',
        r'(\d+)-(\d+)\s*[Rr]aciones?',
        r'[Pp]ara (\d+) personas?'  
    ]

    for patron in patrones:
        match = re.search(patron, texto)
        if match:
            if len(match.groups()) == 2:
                if '-' in texto:
                    return f"{match.group(1)}-{match.group(2)}"
                else:
                    return f"{match.group(1)}/{match.group(2)}"
            return match.group(1)
    return None

def procesar_receta(texto):
    lineas = texto.strip().split('\n')
    nombre = ""
    ingredientes = []
    pasos = []
    raciones = None
    
    paso_actual = ""
    en_paso = False

    for i, linea in enumerate(lineas):
        linea = linea.strip()

        if linea.startswith('[Receta]'):
            nombre = linea.replace('[Receta]', '').strip()
            # Buscar raciones en las siguientes 2 líneas
            for j in range(1, 3):
                if i + j < len(lineas):
                    rac = extraer_raciones(lineas[i + j])
                    if rac:
                        raciones = rac
                        break

        elif linea.startswith('·'):
            ingredientes.append(linea.replace('·', '').strip())

        elif re.match(r'^\d+\)', linea):
            # Detecta paso enumerado
            if paso_actual:
                pasos.append(paso_actual.strip())
            # Inicia nuevo paso
            paso_actual = linea.split(')', 1)[1].strip()
            en_paso= True
        
        elif en_paso and linea:
            paso_actual += " " + linea
    
    if paso_actual:
        pasos.append(paso_actual.strip())

    return {
        'nombre': nombre,
        'raciones': raciones,
        'ingredientes': ingredientes,
        'pasos': pasos
    }

# Leer el PDF
ruta_pdf = "Recetas text.pdf"  
texto_pdf = leer_pdf(ruta_pdf)

if texto_pdf:
    # Dividir el texto en recetas individuales
    recetas_texto = texto_pdf.split('[Receta]')
    recetas_texto = ['[Receta]' + r for r in recetas_texto[1:]]  # Excluir el primer elemento vacío

    # Procesar cada receta
    recetas_procesadas = []
    for receta in recetas_texto:
        datos_receta = procesar_receta(receta)
        recetas_procesadas.append(datos_receta)

    # Crear DataFrame
    df = pd.DataFrame(recetas_procesadas)

    # Mostrar el DataFrame
    print("\nPrimeras filas del DataFrame:")
    print(df.head())

    # Mostrar información sobre el DataFrame
    print("\nInformación del DataFrame:")
    print(df.info())
# Out:
# Primeras filas del DataFrame:
#                                               nombre raciones  \
# 0  Huevos revueltos con de salmón, espinacas y qu...        2
# 1                                    Rollitos de col     None
# 2                             Fumet de gambas (ceto)        2
# 3             Pudding de chía con arándanos y nueces        2
# 4  Ensalada marinera: con aguacate, gambas, bacal...     None
#
#                                         ingredientes  \
# 0  [6 g de aceite de oliva (AOVE), 4 huevos, 20 g...
# 1  [2 hojas de col (tiernas), 150 g de carne pica...
# 2  [200 g de gambas peladas (ver observaciones), ...
# 3  [250 ml leche de almendra, 250 ml de kefir (ca...
# 4  [100 g Gambas, 100 g bacalao ahumado, ½ Aguaca...
#
#                                                pasos
# 0  [Cortar las verduras: cebolla y espinacas y el...
# 1  [Precalentar el horno a 180°C., Hervir 2 hojas...
# 2  [Fundir la mantequilla en una olla grande a fu...
# 3  [Una vez mezclado sirve en dos recipientes (un...
# 4  [Hierve las gambas, Cortar el aguacate y las h...
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        15 non-null     object
#  1   raciones      7 non-null      object
#  2   ingredientes  15 non-null     object
#  3   pasos         15 non-null     object
# dtypes: object(4)
# memory usage: 612.0+ bytes
# None

# %%
# Guardar en CSV
df.to_csv('recetas_con_raciones.csv', index=False)
print("\nArchivo CSV guardado como 'recetas_con_raciones.csv'")
# Out:
# Archivo CSV guardado como 'recetas_con_raciones.csv'

# %%
df.head()
# Out:
#                                               nombre raciones  \
# 0  Huevos revueltos con de salmón, espinacas y qu...        2
# 1                                    Rollitos de col     None
# 2                             Fumet de gambas (ceto)        2
# 3             Pudding de chía con arándanos y nueces        2
# 4  Ensalada marinera: con aguacate, gambas, bacal...     None
#
#                                         ingredientes  \
# 0  [6 g de aceite de oliva (AOVE), 4 huevos, 20 g...
# 1  [2 hojas de col (tiernas), 150 g de carne pica...
# 2  [200 g de gambas peladas (ver observaciones), ...
# 3  [250 ml leche de almendra, 250 ml de kefir (ca...
# 4  [100 g Gambas, 100 g bacalao ahumado, ½ Aguaca...
#
#                                                pasos
# 0  [Cortar las verduras: cebolla y espinacas y el...
# 1  [Precalentar el horno a 180°C., Hervir 2 hojas...
# 2  [Fundir la mantequilla en una olla grande a fu...
# 3  [Una vez mezclado sirve en dos recipientes (un...
# 4  [Hierve las gambas, Cortar el aguacate y las h...

# %% [markdown]
# ## DF INGREDIENTES ESPECÍFICOS

# %%
df_ingredientes = df.explode("ingredientes")

# %%
df_ingredientes = df_ingredientes.groupby(["nombre", "ingredientes"]).sum()

# %%
df_ingredientes = df_ingredientes.drop(columns=["raciones", "pasos"])

# %%
# Vistazo a agrupación por ingredientes
df_ingredientes.head(50)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Ensalada marinera: con aguacate, gambas, bacalao ahumado y, 10 g Aceite de oliva), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, 100 g Gambas), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, 100 g bacalao ahumado), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, 20 g de nueces), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, 70 g Hojas verdes (lechuga, espinacas, rúcula, kale…)), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, Sal y pimienta), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, ½ Aguacate), (Ensalada marinera: con aguacate, gambas, bacalao ahumado y, ½ Limón), (Estofado de ternera con verduras, 1 cucharada de aceite de oliva), (Estofado de ternera con verduras, 1 cucharada de tomate concentrado (opcional)), (Estofado de ternera con verduras, 1 diente de ajo), (Estofado de ternera con verduras, 1 hoja de laurel), (Estofado de ternera con verduras, 1 taza (250 ml) de caldo de carne), (Estofado de ternera con verduras, 1 zanahoria), (Estofado de ternera con verduras, 1/2 cebolla), (Estofado de ternera con verduras, 100 g de judías verdes), (Estofado de ternera con verduras, 400 g de carne de ternera para estofar, troceada), (Estofado de ternera con verduras, Sal y pimienta al gusto), (Estofado de ternera con verduras, ½ cucharadita de tomín), (Fumet de gambas (ceto), 100 g de cebolla blanca), (Fumet de gambas (ceto), 15 g de cebollino o parte verde de una cebolleta), (Fumet de gambas (ceto), 2 dientes de ajo), (Fumet de gambas (ceto), 20 g de mantequilla), (Fumet de gambas (ceto), 200 g de gambas peladas (ver observaciones)), (Fumet de gambas (ceto), 400 g de coliflor), (Fumet de gambas (ceto), 500 ml de caldo de pollo o pescado), (Fumet de gambas (ceto), 60 ml de nata líquida), (Fumet de gambas (ceto), 6g de hojas de cilantro (opcional)), (Fumet de gambas (ceto), Sal al gusto), (Hamburguesa con ensalada, 10 g de aceite de oliva), (Hamburguesa con ensalada, 100g de ensalada verde), (Hamburguesa con ensalada, 200 g de carne de ternera del estofado del otro día), (Hamburguesa con ensalada, 200g de patata prebiótica), (Hamburguesa con ensalada, Sal y pimienta al gusto), (Hamburguesa con ensalada, ¼ de cucharadita de ajo en polvo o ½ ajo fresco), (Hamburguesa con ensalada, ¼ de cucharadita de cebolla en polvo), (Hamburguesa con ensalada, ¼ de cucharadita de mostaza Dijon), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 1 manojo de espinacas), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 100 g de salmón ahumado), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 20 g de cebolla), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 4 huevos), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 40 g de queso feta), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 50 g de queso crema), (Huevos revueltos con de salmón, espinacas y queso crema y feta, 6 g de aceite de oliva (AOVE)), (Merluza con corteza de almendras y parmesano + ensalada verde, 1 solomillo de merluza con piel (300g)), (Merluza con corteza de almendras y parmesano + ensalada verde, 1⁄2 limón), (Merluza con corteza de almendras y parmesano + ensalada verde, 20 g de queso parmesano), (Merluza con corteza de almendras y parmesano + ensalada verde, 25 g de almendras fileteadas), (Merluza con corteza de almendras y parmesano + ensalada verde, 25 g de mantequilla sin sal), (Merluza con corteza de almendras y parmesano + ensalada verde, Sal y pimienta al gusto)]

# %% [markdown]
# ## DF INGREDIENTES + CANTIDAD + UNIDAD

# %%
#Convertimos agrupación en dataframe para obtener nuevas columnas (unidad, cantidad)
df_ingredientes = df_ingredientes.reset_index()

# %%
def process_ingredient(text):  
    if pd.isna(text):  
        return pd.Series({'ingrediente': None, 'cantidad': None, 'unidad': None})  

    text = str(text).strip()  

    # Patrones regex mejorados  
    patterns = [  
        # Patrón para "¼ de cucharadita de Ingrediente"  
        (r'^¼\s*(?:de\s+)?(cucharadita)\s+de\s+(.+)$', lambda m: (m.group(2), '1/4', m.group(1))),
        
        # Patrón para fracciones simples
        
        (r'^(?:1/4|1/2|1/3|¼|½|⅓)\s+(?:de\s+)?(.+)$', lambda m: (m.group(1), m.group(0).split()[0], None)),

        # Patrón para "X g/ml de Ingrediente"  
        (r'^(\d+)\s*(g)\s+(?:de\s+)?(.+)$', lambda m: (m.group(3), m.group(1), m.group(2))),  

        # Patrón para "X cucharada(s)/cucharadita(s) de Ingrediente"  
        (r'^(\d+)\s*(cucharada|cucharadita)s?\s+(?:de\s+)?(.+)$', lambda m: (m.group(3), m.group(1), m.group(2))),  

        # Patrón para "X taza (Y ml) de Ingrediente"  
        (r'^(\d+)\s*taza\s*$(\d+)\s*(ml)$\s*de\s*(.+)$', lambda m: (m.group(4), m.group(2), m.group(3))),  

        # Patrón para fracciones simples "1/2 Ingrediente" o "½ Ingrediente"  
        (r'^(?:1/2|½)\s+(.+)$', lambda m: (m.group(1), '1/2', None)),  

        # Patrón para "X diente(s) de ajo"  
        (r'^(\d+)\s*dientes?\s+de\s+(.+)$', lambda m: (m.group(2), m.group(1), 'unidad')),  

        # Patrón para fracciones con unidades "1/4 de cucharadita/cucharada de Ingrediente"  
        (r'^(?:1/4|¼)\s+(?:de\s+)?(cucharadita|cucharada)\s+de\s+(.+)$', lambda m: (m.group(2), '1/4', m.group(1))),
        
        # Patrón para "X ingrediente(s)"
        (r'^(\d+)\s+(.+)$', lambda m: (m.group(2), m.group(1), 'unidad')),
        
        # Patrón para "X ml" y "X ml de"
        (r'^(\d+)\s*ml(?:\s+de)?\s*(.+)$', lambda m: (m.group(2).strip(), m.group(1), 'ml')),
    ]  

    for pattern, handler in patterns:  
        match = re.match(pattern, text)  
        if match:  
            ingrediente, cantidad, unidad = handler(match)  
            return pd.Series({'ingrediente': ingrediente.strip(), 'cantidad': cantidad, 'unidad': unidad})  

    # Si no coincide con ningún patrón, devolver solo el ingrediente  
    return pd.Series({'ingrediente': text, 'cantidad': None, 'unidad': None})  

# Aplicar la función a cada ingrediente  
df_ingredientes[['ingrediente', 'cantidad', 'unidad']] = df_ingredientes['ingredientes'].apply(process_ingredient)  

# Limpiar y ajustar el resultado  
df_ingredientes['cantidad'] = df_ingredientes['cantidad'].replace('', None)  
df_ingredientes['unidad'] = df_ingredientes['unidad'].map({  
    'g': 'gramos',  
    'ml': 'mililitros',  
    'cucharada': 'cucharada',  
    'cucharadita': 'cucharadita',  
    'unidad': 'unidad'  
})  

# Limpiar paréntesis y texto opcional  
df_ingredientes['ingrediente'] = df_ingredientes['ingrediente'].apply(lambda x: re.sub(r'$[^)]*$', '', str(x)).strip())  
df_ingredientes['ingrediente'] = df_ingredientes['ingrediente'].apply(lambda x: re.sub(r'\s+', ' ', str(x)).strip())

# %%
df_ingredientes.head(50)
# Out:
#                                                nombre  \
# 0   Ensalada marinera: con aguacate, gambas, bacal...
# 1   Ensalada marinera: con aguacate, gambas, bacal...
# 2   Ensalada marinera: con aguacate, gambas, bacal...
# 3   Ensalada marinera: con aguacate, gambas, bacal...
# 4   Ensalada marinera: con aguacate, gambas, bacal...
# 5   Ensalada marinera: con aguacate, gambas, bacal...
# 6   Ensalada marinera: con aguacate, gambas, bacal...
# 7   Ensalada marinera: con aguacate, gambas, bacal...
# 8                    Estofado de ternera con verduras
# 9                    Estofado de ternera con verduras
# 10                   Estofado de ternera con verduras
# 11                   Estofado de ternera con verduras
# 12                   Estofado de ternera con verduras
# 13                   Estofado de ternera con verduras
# 14                   Estofado de ternera con verduras
# 15                   Estofado de ternera con verduras
# 16                   Estofado de ternera con verduras
# 17                   Estofado de ternera con verduras
# 18                   Estofado de ternera con verduras
# 19                             Fumet de gambas (ceto)
# 20                             Fumet de gambas (ceto)
# 21                             Fumet de gambas (ceto)
# 22                             Fumet de gambas (ceto)
# 23                             Fumet de gambas (ceto)
# 24                             Fumet de gambas (ceto)
# 25                             Fumet de gambas (ceto)
# 26                             Fumet de gambas (ceto)
# 27                             Fumet de gambas (ceto)
# 28                             Fumet de gambas (ceto)
# 29                           Hamburguesa con ensalada
# 30                           Hamburguesa con ensalada
# 31                           Hamburguesa con ensalada
# 32                           Hamburguesa con ensalada
# 33                           Hamburguesa con ensalada
# 34                           Hamburguesa con ensalada
# 35                           Hamburguesa con ensalada
# 36                           Hamburguesa con ensalada
# 37  Huevos revueltos con de salmón, espinacas y qu...
# 38  Huevos revueltos con de salmón, espinacas y qu...
# 39  Huevos revueltos con de salmón, espinacas y qu...
# 40  Huevos revueltos con de salmón, espinacas y qu...
# 41  Huevos revueltos con de salmón, espinacas y qu...
# 42  Huevos revueltos con de salmón, espinacas y qu...
# 43  Huevos revueltos con de salmón, espinacas y qu...
# 44  Merluza con corteza de almendras y parmesano +...
# 45  Merluza con corteza de almendras y parmesano +...
# 46  Merluza con corteza de almendras y parmesano +...
# 47  Merluza con corteza de almendras y parmesano +...
# 48  Merluza con corteza de almendras y parmesano +...
# 49  Merluza con corteza de almendras y parmesano +...
#
#                                          ingredientes  \
# 0                                10 g Aceite de oliva
# 1                                        100 g Gambas
# 2                               100 g bacalao ahumado
# 3                                      20 g de nueces
# 4   70 g Hojas verdes (lechuga, espinacas, rúcula,...
# 5                                      Sal y pimienta
# 6                                          ½ Aguacate
# 7                                             ½ Limón
# 8                      1 cucharada de aceite de oliva
# 9        1 cucharada de tomate concentrado (opcional)
# 10                                    1 diente de ajo
# 11                                   1 hoja de laurel
# 12                  1 taza (250 ml) de caldo de carne
# 13                                        1 zanahoria
# 14                                        1/2 cebolla
# 15                             100 g de judías verdes
# 16   400 g de carne de ternera para estofar, troceada
# 17                            Sal y pimienta al gusto
# 18                             ½ cucharadita de tomín
# 19                            100 g de cebolla blanca
# 20   15 g de cebollino o parte verde de una cebolleta
# 21                                   2 dientes de ajo
# 22                                20 g de mantequilla
# 23        200 g de gambas peladas (ver observaciones)
# 24                                  400 g de coliflor
# 25                 500 ml de caldo de pollo o pescado
# 26                              60 ml de nata líquida
# 27                 6g de hojas de cilantro (opcional)
# 28                                       Sal al gusto
# 29                            10 g de aceite de oliva
# 30                             100g de ensalada verde
# 31  200 g de carne de ternera del estofado del otr...
# 32                          200g de patata prebiótica
# 33                            Sal y pimienta al gusto
# 34    ¼ de cucharadita de ajo en polvo o ½ ajo fresco
# 35               ¼ de cucharadita de cebolla en polvo
# 36                  ¼ de cucharadita de mostaza Dijon
# 37                              1 manojo de espinacas
# 38                            100 g de salmón ahumado
# 39                                    20 g de cebolla
# 40                                           4 huevos
# 41                                 40 g de queso feta
# 42                                50 g de queso crema
# 43                      6 g de aceite de oliva (AOVE)
# 44             1 solomillo de merluza con piel (300g)
# 45                                          1⁄2 limón
# 46                            20 g de queso parmesano
# 47                       25 g de almendras fileteadas
# 48                        25 g de mantequilla sin sal
# 49                            Sal y pimienta al gusto
#
#                                          ingrediente cantidad       unidad
# 0                                    Aceite de oliva       10       gramos
# 1                                             Gambas      100       gramos
# 2                                    bacalao ahumado      100       gramos
# 3                                             nueces       20       gramos
# 4   Hojas verdes (lechuga, espinacas, rúcula, kale…)       70       gramos
# 5                                     Sal y pimienta     None          NaN
# 6                                           Aguacate        ½          NaN
# 7                                              Limón        ½          NaN
# 8                                    aceite de oliva        1    cucharada
# 9                      tomate concentrado (opcional)        1    cucharada
# 10                                               ajo        1       unidad
# 11                                    hoja de laurel        1       unidad
# 12                   taza (250 ml) de caldo de carne        1       unidad
# 13                                         zanahoria        1       unidad
# 14                                           cebolla      1/2          NaN
# 15                                     judías verdes      100       gramos
# 16           carne de ternera para estofar, troceada      400       gramos
# 17                           Sal y pimienta al gusto     None          NaN
# 18                              cucharadita de tomín        ½          NaN
# 19                                    cebolla blanca      100       gramos
# 20          cebollino o parte verde de una cebolleta       15       gramos
# 21                                               ajo        2       unidad
# 22                                       mantequilla       20       gramos
# 23                gambas peladas (ver observaciones)      200       gramos
# 24                                          coliflor      400       gramos
# 25                    ml de caldo de pollo o pescado      500       unidad
# 26                                ml de nata líquida       60       unidad
# 27                      hojas de cilantro (opcional)        6       gramos
# 28                                      Sal al gusto     None          NaN
# 29                                   aceite de oliva       10       gramos
# 30                                    ensalada verde      100       gramos
# 31        carne de ternera del estofado del otro día      200       gramos
# 32                                 patata prebiótica      200       gramos
# 33                           Sal y pimienta al gusto     None          NaN
# 34                       ajo en polvo o ½ ajo fresco      1/4  cucharadita
# 35                                  cebolla en polvo      1/4  cucharadita
# 36                                     mostaza Dijon      1/4  cucharadita
# 37                               manojo de espinacas        1       unidad
# 38                                    salmón ahumado      100       gramos
# 39                                           cebolla       20       gramos
# 40                                            huevos        4       unidad
# 41                                        queso feta       40       gramos
# 42                                       queso crema       50       gramos
# 43                            aceite de oliva (AOVE)        6       gramos
# 44              solomillo de merluza con piel (300g)        1       unidad
# 45                                         1⁄2 limón     None          NaN
# 46                                   queso parmesano       20       gramos
# 47                              almendras fileteadas       25       gramos
# 48                               mantequilla sin sal       25       gramos
# 49                           Sal y pimienta al gusto     None          NaN

# %% [markdown]
# ### INGREDIENTES + CANTIDAD + UNIDAD (Limpieza)

# %%
# Regex para limpiar "X ml + de + ingrediente"  

pattern = r'(\d+)\s*(ml)\s*de\s*(.*)'  

for idx, row in df_ingredientes.iterrows():  
    text = str(row["ingredientes"])   
    match = re.match(pattern, text)  

    if match:    
        cantidad = int(match.group(1))    
        ingrediente = match.group(3)  
 
        df_ingredientes.at[idx, "ingrediente"] = ingrediente  
        df_ingredientes.at[idx, "cantidad"] = cantidad  
        df_ingredientes.at[idx, "unidad"] = "mililitros"

# %% [markdown]
# #### Kg en ingredientes (Limpieza)

# %%
# Localizando Kg en ingredientes para manipularlo

df_ingredientes[df_ingredientes["ingredientes"].str.contains("kg", na=False)]
# Out:
#                nombre                                       ingredientes  \
# 61  Pastel de pescado  1 kg de pescado limpio y desmenuzado (rap qued...
#
#                                           ingrediente cantidad  unidad
# 61  kg de pescado limpio y desmenuzado (rap queda ...        1  unidad

# %%
df_ingredientes.loc[61]["ingredientes"]
# Out:
# '1 kg de pescado limpio y desmenuzado (rap queda muy bien, sino también puedes'

# %%
# Cambiamos valores de forma manual al ser un caso aislado

df_ingredientes.loc[61, "ingrediente"] = "pescado limpio y desmenuzado"
df_ingredientes.loc[61, "unidad"] = "kilogramo"

# %%
df_ingredientes.loc[61]
# Out:
# nombre                                          Pastel de pescado
# ingredientes    1 kg de pescado limpio y desmenuzado (rap qued...
# ingrediente                          pescado limpio y desmenuzado
# cantidad                                                        1
# unidad                                                  kilogramo
# Name: 61, dtype: object

# %% [markdown]
# #### Cantidad 1/2 y 1/4 a 0.5 y 0.25 (Limpieza)

# %%
# Indentificar cuantos tenemos

df_ingredientes[(df_ingredientes["cantidad"] == "1/2") |
               (df_ingredientes["cantidad"] == "1/4") |
               (df_ingredientes["cantidad"] == "½") |
               (df_ingredientes["cantidad"] == "¼")
               ]
# Out:
#                                                 nombre  \
# 6    Ensalada marinera: con aguacate, gambas, bacal...
# 7    Ensalada marinera: con aguacate, gambas, bacal...
# 14                    Estofado de ternera con verduras
# 18                    Estofado de ternera con verduras
# 34                            Hamburguesa con ensalada
# 35                            Hamburguesa con ensalada
# 36                            Hamburguesa con ensalada
# 75      Piteras de pollo con champiñones y salsa crema
# 79      Piteras de pollo con champiñones y salsa crema
# 80      Piteras de pollo con champiñones y salsa crema
# 104                      Revuelto de espárragos y feta
#
#                                         ingredientes  \
# 6                                         ½ Aguacate
# 7                                            ½ Limón
# 14                                       1/2 cebolla
# 18                            ½ cucharadita de tomín
# 34   ¼ de cucharadita de ajo en polvo o ½ ajo fresco
# 35              ¼ de cucharadita de cebolla en polvo
# 36                 ¼ de cucharadita de mostaza Dijon
# 75                                    1/4 de cebolla
# 79               ¼ de taza (60 ml) de caldo de pollo
# 80        ¼ de taza (60 ml) de crema de leche (nata)
# 104                                        ½ cebolla
#
#                                ingrediente cantidad       unidad
# 6                                 Aguacate        ½          NaN
# 7                                    Limón        ½          NaN
# 14                                 cebolla      1/2          NaN
# 18                    cucharadita de tomín        ½          NaN
# 34             ajo en polvo o ½ ajo fresco      1/4  cucharadita
# 35                        cebolla en polvo      1/4  cucharadita
# 36                           mostaza Dijon      1/4  cucharadita
# 75                                 cebolla      1/4          NaN
# 79          taza (60 ml) de caldo de pollo        ¼          NaN
# 80   taza (60 ml) de crema de leche (nata)        ¼          NaN
# 104                                cebolla        ½          NaN

# %%
for idx, row in df_ingredientes.iterrows():
    if row["cantidad"] == "½" or row["cantidad"] =="1/2":
        df_ingredientes.at[idx, "ingrediente"] = "1/2" + " " + row["ingrediente"]
        df_ingredientes.at[idx, "cantidad"] = None
        df_ingredientes.at[idx, "unidad"] = None
    
    if row["cantidad"] == "¼" or row["cantidad"] == "1/4":
        df_ingredientes.at[idx, "ingrediente"] = "1/4" + " " + row["ingrediente"]
        df_ingredientes.at[idx, "cantidad"] = None
        df_ingredientes.at[idx, "unidad"] = None

# %% [markdown]
# ### CANTIDAD A NUMÉRICO

# %%
df_ingredientes["cantidad"] = pd.to_numeric(df_ingredientes["cantidad"])
df_ingredientes["cantidad"] = df_ingredientes["cantidad"].astype("Int64")

# %%
df_ingredientes.dtypes
# Out:
# nombre          object
# ingredientes    object
# ingrediente     object
# cantidad         Int64
# unidad          object
# dtype: object

# %% [markdown]
# ### NULOS A VALORES A INTERPRETAR

# %%
df_ingredientes.isna().sum()
# Out:
# nombre           0
# ingredientes     0
# ingrediente      0
# cantidad        35
# unidad          35
# dtype: int64

# %%
df_ingredientes["cantidad"] = df_ingredientes["cantidad"].fillna(1)
df_ingredientes["unidad"] = df_ingredientes["unidad"].fillna("unidad")

# %%
df_ingredientes.isna().sum()
# Out:
# nombre          0
# ingredientes    0
# ingrediente     0
# cantidad        0
# unidad          0
# dtype: int64

# %%
df_ingredientes.head(50)
# Out:
#                                                nombre  \
# 0   Ensalada marinera: con aguacate, gambas, bacal...
# 1   Ensalada marinera: con aguacate, gambas, bacal...
# 2   Ensalada marinera: con aguacate, gambas, bacal...
# 3   Ensalada marinera: con aguacate, gambas, bacal...
# 4   Ensalada marinera: con aguacate, gambas, bacal...
# 5   Ensalada marinera: con aguacate, gambas, bacal...
# 6   Ensalada marinera: con aguacate, gambas, bacal...
# 7   Ensalada marinera: con aguacate, gambas, bacal...
# 8                    Estofado de ternera con verduras
# 9                    Estofado de ternera con verduras
# 10                   Estofado de ternera con verduras
# 11                   Estofado de ternera con verduras
# 12                   Estofado de ternera con verduras
# 13                   Estofado de ternera con verduras
# 14                   Estofado de ternera con verduras
# 15                   Estofado de ternera con verduras
# 16                   Estofado de ternera con verduras
# 17                   Estofado de ternera con verduras
# 18                   Estofado de ternera con verduras
# 19                             Fumet de gambas (ceto)
# 20                             Fumet de gambas (ceto)
# 21                             Fumet de gambas (ceto)
# 22                             Fumet de gambas (ceto)
# 23                             Fumet de gambas (ceto)
# 24                             Fumet de gambas (ceto)
# 25                             Fumet de gambas (ceto)
# 26                             Fumet de gambas (ceto)
# 27                             Fumet de gambas (ceto)
# 28                             Fumet de gambas (ceto)
# 29                           Hamburguesa con ensalada
# 30                           Hamburguesa con ensalada
# 31                           Hamburguesa con ensalada
# 32                           Hamburguesa con ensalada
# 33                           Hamburguesa con ensalada
# 34                           Hamburguesa con ensalada
# 35                           Hamburguesa con ensalada
# 36                           Hamburguesa con ensalada
# 37  Huevos revueltos con de salmón, espinacas y qu...
# 38  Huevos revueltos con de salmón, espinacas y qu...
# 39  Huevos revueltos con de salmón, espinacas y qu...
# 40  Huevos revueltos con de salmón, espinacas y qu...
# 41  Huevos revueltos con de salmón, espinacas y qu...
# 42  Huevos revueltos con de salmón, espinacas y qu...
# 43  Huevos revueltos con de salmón, espinacas y qu...
# 44  Merluza con corteza de almendras y parmesano +...
# 45  Merluza con corteza de almendras y parmesano +...
# 46  Merluza con corteza de almendras y parmesano +...
# 47  Merluza con corteza de almendras y parmesano +...
# 48  Merluza con corteza de almendras y parmesano +...
# 49  Merluza con corteza de almendras y parmesano +...
#
#                                          ingredientes  \
# 0                                10 g Aceite de oliva
# 1                                        100 g Gambas
# 2                               100 g bacalao ahumado
# 3                                      20 g de nueces
# 4   70 g Hojas verdes (lechuga, espinacas, rúcula,...
# 5                                      Sal y pimienta
# 6                                          ½ Aguacate
# 7                                             ½ Limón
# 8                      1 cucharada de aceite de oliva
# 9        1 cucharada de tomate concentrado (opcional)
# 10                                    1 diente de ajo
# 11                                   1 hoja de laurel
# 12                  1 taza (250 ml) de caldo de carne
# 13                                        1 zanahoria
# 14                                        1/2 cebolla
# 15                             100 g de judías verdes
# 16   400 g de carne de ternera para estofar, troceada
# 17                            Sal y pimienta al gusto
# 18                             ½ cucharadita de tomín
# 19                            100 g de cebolla blanca
# 20   15 g de cebollino o parte verde de una cebolleta
# 21                                   2 dientes de ajo
# 22                                20 g de mantequilla
# 23        200 g de gambas peladas (ver observaciones)
# 24                                  400 g de coliflor
# 25                 500 ml de caldo de pollo o pescado
# 26                              60 ml de nata líquida
# 27                 6g de hojas de cilantro (opcional)
# 28                                       Sal al gusto
# 29                            10 g de aceite de oliva
# 30                             100g de ensalada verde
# 31  200 g de carne de ternera del estofado del otr...
# 32                          200g de patata prebiótica
# 33                            Sal y pimienta al gusto
# 34    ¼ de cucharadita de ajo en polvo o ½ ajo fresco
# 35               ¼ de cucharadita de cebolla en polvo
# 36                  ¼ de cucharadita de mostaza Dijon
# 37                              1 manojo de espinacas
# 38                            100 g de salmón ahumado
# 39                                    20 g de cebolla
# 40                                           4 huevos
# 41                                 40 g de queso feta
# 42                                50 g de queso crema
# 43                      6 g de aceite de oliva (AOVE)
# 44             1 solomillo de merluza con piel (300g)
# 45                                          1⁄2 limón
# 46                            20 g de queso parmesano
# 47                       25 g de almendras fileteadas
# 48                        25 g de mantequilla sin sal
# 49                            Sal y pimienta al gusto
#
#                                          ingrediente  cantidad      unidad
# 0                                    Aceite de oliva        10      gramos
# 1                                             Gambas       100      gramos
# 2                                    bacalao ahumado       100      gramos
# 3                                             nueces        20      gramos
# 4   Hojas verdes (lechuga, espinacas, rúcula, kale…)        70      gramos
# 5                                     Sal y pimienta         1      unidad
# 6                                       1/2 Aguacate         1      unidad
# 7                                          1/2 Limón         1      unidad
# 8                                    aceite de oliva         1   cucharada
# 9                      tomate concentrado (opcional)         1   cucharada
# 10                                               ajo         1      unidad
# 11                                    hoja de laurel         1      unidad
# 12                   taza (250 ml) de caldo de carne         1      unidad
# 13                                         zanahoria         1      unidad
# 14                                       1/2 cebolla         1      unidad
# 15                                     judías verdes       100      gramos
# 16           carne de ternera para estofar, troceada       400      gramos
# 17                           Sal y pimienta al gusto         1      unidad
# 18                          1/2 cucharadita de tomín         1      unidad
# 19                                    cebolla blanca       100      gramos
# 20          cebollino o parte verde de una cebolleta        15      gramos
# 21                                               ajo         2      unidad
# 22                                       mantequilla        20      gramos
# 23                gambas peladas (ver observaciones)       200      gramos
# 24                                          coliflor       400      gramos
# 25                          caldo de pollo o pescado       500  mililitros
# 26                                      nata líquida        60  mililitros
# 27                      hojas de cilantro (opcional)         6      gramos
# 28                                      Sal al gusto         1      unidad
# 29                                   aceite de oliva        10      gramos
# 30                                    ensalada verde       100      gramos
# 31        carne de ternera del estofado del otro día       200      gramos
# 32                                 patata prebiótica       200      gramos
# 33                           Sal y pimienta al gusto         1      unidad
# 34                   1/4 ajo en polvo o ½ ajo fresco         1      unidad
# 35                              1/4 cebolla en polvo         1      unidad
# 36                                 1/4 mostaza Dijon         1      unidad
# 37                               manojo de espinacas         1      unidad
# 38                                    salmón ahumado       100      gramos
# 39                                           cebolla        20      gramos
# 40                                            huevos         4      unidad
# 41                                        queso feta        40      gramos
# 42                                       queso crema        50      gramos
# 43                            aceite de oliva (AOVE)         6      gramos
# 44              solomillo de merluza con piel (300g)         1      unidad
# 45                                         1⁄2 limón         1      unidad
# 46                                   queso parmesano        20      gramos
# 47                              almendras fileteadas        25      gramos
# 48                               mantequilla sin sal        25      gramos
# 49                           Sal y pimienta al gusto         1      unidad

# %% [markdown]
# ### PREPARADO Y GUARDADO DE CSV: recetas_ingredientes_cantidades

# %%
# Seleccionamos solo las columnas finales

df_ing_cant = df_ingredientes.drop(columns={"ingredientes"})

# %%
# Estandarizamos el texto en "ingredientes". Primera en mayus

df_ing_cant["ingrediente"] = df_ing_cant["ingrediente"].str.lower()

# %%
# Eliminamos espacios a ambos lados de los valores string en variables

columnas_string = ['ingrediente', 'nombre', 'unidad']  
for columna in columnas_string:
    df_ing_cant[columna] = df_ingredientes[columna].str.strip()

# %%
# Observamos algunos valores en "ingrediente" que necesitan estandarización

df_ing_cant[df_ing_cant["ingrediente"].str.contains("sal ")]
# Out:
#                                                 nombre  \
# 5    Ensalada marinera: con aguacate, gambas, bacal...
# 17                    Estofado de ternera con verduras
# 33                            Hamburguesa con ensalada
# 49   Merluza con corteza de almendras y parmesano +...
# 69                                   Pastel de pescado
# 78      Piteras de pollo con champiñones y salsa crema
# 103                      Revuelto de espárragos y feta
# 114                                    Rollitos de col
# 123            Salmón a la plancha con salsa y brócoli
# 124            Salmón a la plancha con salsa y brócoli
#
#                                ingrediente  cantidad  unidad
# 5                           sal y pimienta         1  unidad
# 17                          sal y pimienta         1  unidad
# 33                          sal y pimienta         1  unidad
# 49                          sal y pimienta         1  unidad
# 69                          sal y pimienta         1  unidad
# 78                          sal y pimienta         1  unidad
# 103                         sal y pimienta         1  unidad
# 114                         sal y pimienta         1  unidad
# 123                         sal y pimienta         1  unidad
# 124  sal y pimienta al gusto (salsa limón)         1  unidad

# %%
df_ing_cant["ingrediente"] = df_ing_cant["ingrediente"].replace("sal y pimienta al gusto", "sal y pimienta")
df_ing_cant["ingrediente"] = df_ing_cant["ingrediente"].replace("sal y pimienta buena", "sal y pimienta")
df_ing_cant["ingrediente"] = df_ing_cant["ingrediente"].replace("sal al gusto", "sal")

# %%
print(f"Recetas:")
print(f"\n{df_ing_cant['nombre'].unique()}")
print(f"\n N total de recetas: {df_ing_cant['nombre'].nunique()}")
# Out:
# Recetas:
#
# ['Ensalada marinera: con aguacate, gambas, bacalao ahumado y'
#  'Estofado de ternera con verduras' 'Fumet de gambas (ceto)'
#  'Hamburguesa con ensalada'
#  'Huevos revueltos con de salmón, espinacas y queso crema y feta'
#  'Merluza con corteza de almendras y parmesano + ensalada verde'
#  'Pastel de chocolate' 'Pastel de pescado'
#  'Piteras de pollo con champiñones y salsa crema'
#  'Pizza con base de coliflor' 'Pudding de chía con arándanos y nueces'
#  'Revuelto de espárragos y feta' 'Rollitos de col'
#  'Salmón a la plancha con salsa y brócoli'
#  'Yogur griego con fresas, almendras y nueces.']
#
#  N total de recetas: 15

# %%
df_ing_cant.to_csv("recetas_ingredientes_cantidades.csv")

# %% [markdown]
# ### BORRADOR/ CAMPO PRUEBAS

# %%
df_ing_cant.groupby(["ingrediente", "unidad"])["cantidad"].sum().reset_index().head(10)
# Out:
#                           ingrediente  unidad  cantidad
# 0                         0.5g de sal  unidad         1
# 1                        1/2 aguacate  unidad         1
# 2                         1/2 cebolla  unidad         2
# 3            1/2 cucharadita de tomín  unidad         1
# 4                           1/2 limón  unidad         1
# 5     1/4 ajo en polvo o ½ ajo fresco  unidad         1
# 6                         1/4 cebolla  unidad         1
# 7                1/4 cebolla en polvo  unidad         1
# 8                   1/4 mostaza dijon  unidad         1
# 9  1/4 taza (60 ml) de caldo de pollo  unidad         1

# %%
df_ing_cant.groupby(["nombre", "ingrediente"]).sum().head(50)
# Out:
#                                                                                                      cantidad  \
# nombre                                             ingrediente
# Ensalada marinera: con aguacate, gambas, bacala... 1/2 aguacate                                             1
#                                                    1/2 limón                                                1
#                                                    aceite de oliva                                         10
#                                                    bacalao ahumado                                        100
#                                                    gambas                                                 100
#                                                    hojas verdes (lechuga, espinacas, rúcula, kale…)        70
#                                                    nueces                                                  20
#                                                    sal y pimienta                                           1
# Estofado de ternera con verduras                   1/2 cebolla                                              1
#                                                    1/2 cucharadita de tomín                                 1
#                                                    aceite de oliva                                          1
#                                                    ajo                                                      1
#                                                    carne de ternera para estofar, troceada                400
#                                                    hoja de laurel                                           1
#                                                    judías verdes                                          100
#                                                    sal y pimienta                                           1
#                                                    taza (250 ml) de caldo de carne                          1
#                                                    tomate concentrado (opcional)                            1
#                                                    zanahoria                                                1
# Fumet de gambas (ceto)                             ajo                                                      2
#                                                    caldo de pollo o pescado                               500
#                                                    cebolla blanca                                         100
#                                                    cebollino o parte verde de una cebolleta                15
#                                                    coliflor                                               400
#                                                    gambas peladas (ver observaciones)                     200
#                                                    hojas de cilantro (opcional)                             6
#                                                    mantequilla                                             20
#                                                    nata líquida                                            60
#                                                    sal                                                      1
# Hamburguesa con ensalada                           1/4 ajo en polvo o ½ ajo fresco                          1
#                                                    1/4 cebolla en polvo                                     1
#                                                    1/4 mostaza dijon                                        1
#                                                    aceite de oliva                                         10
#                                                    carne de ternera del estofado del otro día             200
#                                                    ensalada verde                                         100
#                                                    patata prebiótica                                      200
#                                                    sal y pimienta                                           1
# Huevos revueltos con de salmón, espinacas y que... aceite de oliva (aove)                                   6
#                                                    cebolla                                                 20
#                                                    huevos                                                   4
#                                                    manojo de espinacas                                      1
#                                                    queso crema                                             50
#                                                    queso feta                                              40
#                                                    salmón ahumado                                         100
# Merluza con corteza de almendras y parmesano + ... 1⁄2 limón                                                1
#                                                    almendras fileteadas                                    25
#                                                    mantequilla sin sal                                     25
#                                                    queso parmesano                                         20
#                                                    sal y pimienta                                           1
#                                                    solomillo de merluza con piel (300g)                     1
#
#                                                                                                          unidad
# nombre                                             ingrediente
# Ensalada marinera: con aguacate, gambas, bacala... 1/2 aguacate                                          unidad
#                                                    1/2 limón                                             unidad
#                                                    aceite de oliva                                       gramos
#                                                    bacalao ahumado                                       gramos
#                                                    gambas                                                gramos
#                                                    hojas verdes (lechuga, espinacas, rúcula, kale…)      gramos
#                                                    nueces                                                gramos
#                                                    sal y pimienta                                        unidad
# Estofado de ternera con verduras                   1/2 cebolla                                           unidad
#                                                    1/2 cucharadita de tomín                              unidad
#                                                    aceite de oliva                                    cucharada
#                                                    ajo                                                   unidad
#                                                    carne de ternera para estofar, troceada               gramos
#                                                    hoja de laurel                                        unidad
#                                                    judías verdes                                         gramos
#                                                    sal y pimienta                                        unidad
#                                                    taza (250 ml) de caldo de carne                       unidad
#                                                    tomate concentrado (opcional)                      cucharada
#                                                    zanahoria                                             unidad
# Fumet de gambas (ceto)                             ajo                                                   unidad
#                                                    caldo de pollo o pescado                          mililitros
#                                                    cebolla blanca                                        gramos
#                                                    cebollino o parte verde de una cebolleta              gramos
#                                                    coliflor                                              gramos
#                                                    gambas peladas (ver observaciones)                    gramos
#                                                    hojas de cilantro (opcional)                          gramos
#                                                    mantequilla                                           gramos
#                                                    nata líquida                                      mililitros
#                                                    sal                                                   unidad
# Hamburguesa con ensalada                           1/4 ajo en polvo o ½ ajo fresco                       unidad
#                                                    1/4 cebolla en polvo                                  unidad
#                                                    1/4 mostaza dijon                                     unidad
#                                                    aceite de oliva                                       gramos
#                                                    carne de ternera del estofado del otro día            gramos
#                                                    ensalada verde                                        gramos
#                                                    patata prebiótica                                     gramos
#                                                    sal y pimienta                                        unidad
# Huevos revueltos con de salmón, espinacas y que... aceite de oliva (aove)                                gramos
#                                                    cebolla                                               gramos
#                                                    huevos                                                unidad
#                                                    manojo de espinacas                                   unidad
#                                                    queso crema                                           gramos
#                                                    queso feta                                            gramos
#                                                    salmón ahumado                                        gramos
# Merluza con corteza de almendras y parmesano + ... 1⁄2 limón                                             unidad
#                                                    almendras fileteadas                                  gramos
#                                                    mantequilla sin sal                                   gramos
#                                                    queso parmesano                                       gramos
#                                                    sal y pimienta                                        unidad
#                                                    solomillo de merluza con piel (300g)                  unidad

# %%
df_ing_cant.sort_values(by="ingrediente").head(50)
# Out:
#                                                 nombre  \
# 50                                 Pastel de chocolate
# 6    Ensalada marinera: con aguacate, gambas, bacal...
# 104                      Revuelto de espárragos y feta
# 14                    Estofado de ternera con verduras
# 18                    Estofado de ternera con verduras
# 7    Ensalada marinera: con aguacate, gambas, bacal...
# 34                            Hamburguesa con ensalada
# 75      Piteras de pollo con champiñones y salsa crema
# 35                            Hamburguesa con ensalada
# 36                            Hamburguesa con ensalada
# 79      Piteras de pollo con champiñones y salsa crema
# 80      Piteras de pollo con champiñones y salsa crema
# 45   Merluza con corteza de almendras y parmesano +...
# 0    Ensalada marinera: con aguacate, gambas, bacal...
# 29                            Hamburguesa con ensalada
# 8                     Estofado de ternera con verduras
# 117            Salmón a la plancha con salsa y brócoli
# 99                       Revuelto de espárragos y feta
# 73      Piteras de pollo con champiñones y salsa crema
# 43   Huevos revueltos con de salmón, espinacas y qu...
# 60                                 Pastel de chocolate
# 98                       Revuelto de espárragos y feta
# 105                                    Rollitos de col
# 10                    Estofado de ternera con verduras
# 71      Piteras de pollo con champiñones y salsa crema
# 21                              Fumet de gambas (ceto)
# 116            Salmón a la plancha con salsa y brócoli
# 126       Yogur griego con fresas, almendras y nueces.
# 47   Merluza con corteza de almendras y parmesano +...
# 96              Pudding de chía con arándanos y nueces
# 2    Ensalada marinera: con aguacate, gambas, bacal...
# 64                                   Pastel de pescado
# 119            Salmón a la plancha con salsa y brócoli
# 52                                 Pastel de chocolate
# 25                              Fumet de gambas (ceto)
# 72      Piteras de pollo con champiñones y salsa crema
# 31                            Hamburguesa con ensalada
# 16                    Estofado de ternera con verduras
# 108                                    Rollitos de col
# 39   Huevos revueltos con de salmón, espinacas y qu...
# 19                              Fumet de gambas (ceto)
# 109                                    Rollitos de col
# 20                              Fumet de gambas (ceto)
# 76      Piteras de pollo con champiñones y salsa crema
# 57                                 Pastel de chocolate
# 24                              Fumet de gambas (ceto)
# 84                          Pizza con base de coliflor
# 115            Salmón a la plancha con salsa y brócoli
# 30                            Hamburguesa con ensalada
# 58                                 Pastel de chocolate
#
#                                     ingrediente  cantidad      unidad
# 50                                  0.5g de sal         1      unidad
# 6                                  1/2 aguacate         1      unidad
# 104                                 1/2 cebolla         1      unidad
# 14                                  1/2 cebolla         1      unidad
# 18                     1/2 cucharadita de tomín         1      unidad
# 7                                     1/2 limón         1      unidad
# 34              1/4 ajo en polvo o ½ ajo fresco         1      unidad
# 75                                  1/4 cebolla         1      unidad
# 35                         1/4 cebolla en polvo         1      unidad
# 36                            1/4 mostaza dijon         1      unidad
# 79           1/4 taza (60 ml) de caldo de pollo         1      unidad
# 80    1/4 taza (60 ml) de crema de leche (nata)         1      unidad
# 45                                    1⁄2 limón         1      unidad
# 0                               aceite de oliva        10      gramos
# 29                              aceite de oliva        10      gramos
# 8                               aceite de oliva         1   cucharada
# 117                             aceite de oliva        10      gramos
# 99                              aceite de oliva         1   cucharada
# 73                        aceite de oliva (10g)         1   cucharada
# 43                       aceite de oliva (aove)         6      gramos
# 60                                     aguacate        50      gramos
# 98                                          ajo         1      unidad
# 105                                         ajo         1      unidad
# 10                                          ajo         1      unidad
# 71                                          ajo         1      unidad
# 21                                          ajo         2      unidad
# 116                   ajo, picado (salsa limón)         1      unidad
# 126                                   almendras        20      gramos
# 47                         almendras fileteadas        25      gramos
# 96                                    arándanos        50      gramos
# 2                               bacalao ahumado       100      gramos
# 64                             blancos de huevo         2      unidad
# 119                                      brécol       100      gramos
# 52                    cacao en polvo sin azúcar        10      gramos
# 25                     caldo de pollo o pescado       500  mililitros
# 72                      cantera de pollo (250g)         1      unidad
# 31   carne de ternera del estofado del otro día       200      gramos
# 16      carne de ternera para estofar, troceada       400      gramos
# 108                                carne picada       150      gramos
# 39                                      cebolla        20      gramos
# 19                               cebolla blanca       100      gramos
# 109                             cebolla, picada         2      gramos
# 20     cebollino o parte verde de una cebolleta        15      gramos
# 76                                  champiñones        70      gramos
# 57                                chocolate 90%        40      gramos
# 24                                     coliflor       400      gramos
# 84                                     coliflor       400      gramos
# 115                     corte de salmón (150 g)         1      unidad
# 30                               ensalada verde       100      gramos
# 58                                    eritritol        40      gramos
